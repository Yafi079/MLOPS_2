# %% [markdown]
# **Mengimpor Modul untuk Menjalankan Pipeline TFX dengan Apache Beam**
#
# Kode ini mengimpor modul `os`, `components`, dan `pipeline` dari folder `modules`, serta `BeamDagRunner` dari `tfx.orchestration.beam.beam_dag_runner`. Fungsinya adalah untuk mengatur dan menjalankan pipeline TFX menggunakan runner Beam, yang memungkinkan eksekusi pipeline pada berbagai backend yang didukung oleh Apache Beam.

# %%
import os
from modules import components, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %% [markdown]
# **Mengatur Parameter dan Path untuk Pipeline TFX**
#
# Kode ini menetapkan nama pipeline, menentukan path untuk data input, modul transformasi, modul tuner, dan modul pelatihan, serta menentukan path untuk output pipeline seperti model yang telah dilayani dan metadata. Fungsinya adalah untuk mengonfigurasi dan menyiapkan parameter yang diperlukan untuk komponen pipeline TFX, yang akan digunakan saat pipeline dijalankan.

# %%
PIPELINE_NAME = "muhammad_yafi_079-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/transform.py"
TUNER_MODULE_FILE = "modules/tuner.py"
TRAINER_MODULE_FILE = "modules/trainer.py"

# Pipeline outputs
OUTPUT_BASE = "output"

serving_model_dir = os.path.join(OUTPUT_BASE, "serving_model")
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# Parameter untuk komponen
components_args = {
    "data_dir": DATA_ROOT,
    "transform_module": TRANSFORM_MODULE_FILE,
    "training_module": TRAINER_MODULE_FILE,
    "tuner_module": TUNER_MODULE_FILE,
    "training_steps": 1000,
    "eval_steps": 800,
    "serving_model_dir": serving_model_dir,
}

# %% [markdown]
# **Inisialisasi Komponen Pipeline TFX**
#
# Kode ini memanggil fungsi `init_components` dari modul `components` dengan argumen yang ditentukan dalam `components_args`. Fungsinya adalah untuk menginisialisasi semua komponen yang diperlukan untuk pipeline TFX berdasarkan konfigurasi yang telah disiapkan sebelumnya.

# %%
komponen = components.init_components(**components_args)

# %% [markdown]
# **Menjalankan Pipeline TFX dengan Apache Beam**
#
# Kode ini menginisialisasi objek pipeline TFX dengan memanggil `init_pipeline` dari modul `pipeline`, menggunakan parameter seperti `pipeline_root`, `pipeline_name`, `metadata_path`, dan komponen yang telah diinisialisasi. Kemudian, pipeline dijalankan menggunakan `BeamDagRunner`, yang mengeksekusi pipeline pada backend yang didukung oleh Apache Beam.

# %%
pipeline_obj = pipeline.init_pipeline(
    pipeline_root=pipeline_root,
    pipeline_name=PIPELINE_NAME,
    metadata_path=metadata_path,
    components=komponen
)

BeamDagRunner().run(pipeline=pipeline_obj)
# Out:
# Trial 10 Complete [00h 00m 26s]
# binary_accuracy: 0.9563593864440918
#
# Best binary_accuracy So Far: 0.9635781049728394
# Total elapsed time: 00h 02m 36s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Int', 'config': {'name': 'n_layers', 'default': None, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': None}}, {'class_name': 'Int', 'config': {'name': 'dense_units', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 32, 'sampling': None}}, {'class_name': 'Choice', 'config': {'name': 'lr', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'n_layers': 5, 'dense_units': 48, 'lr': 0.001, 'tuner/epochs': 5, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}}
# INFO:absl:Best Hyperparameters are written to output\muhammad_yafi_079-pipeline\Tuner\best_hyperparameters\17\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\muhammad_yafi_079-pipeline\Tuner\tuner_results\17\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 17 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'tuner_results': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Tuner\\tuner_results\\17"
# , artifact_type: name: "TunerResults"
# )], 'best_hyperparameters': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Tuner\\best_hyperparameters\\17"
# , artifact_type: name: "HyperParameters"
# )]}) for execution 17
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# Results summary
# Results in output\muhammad_yafi_079-pipeline\Tuner\.system\executor_execution\17\.temp\17\kt_hyperband
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000020FA83747C0>
# Trial summary
# Hyperparameters:
# n_layers: 5
# dense_units: 48
# lr: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9635781049728394
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 112
# lr: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9563593864440918
# Trial summary
# Hyperparameters:
# n_layers: 5
# dense_units: 80
# lr: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9525781273841858
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 112
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0000
# Score: 0.9505312442779541
# Trial summary
# Hyperparameters:
# n_layers: 3
# dense_units: 112
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9504843950271606
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 16
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.950390636920929
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 16
# lr: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0001
# Score: 0.9503594040870667
# Trial summary
# Hyperparameters:
# n_layers: 5
# dense_units: 16
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9502343535423279
# Trial summary
# Hyperparameters:
# n_layers: 2
# dense_units: 80
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9501718878746033
# Trial summary
# Hyperparameters:
# n_layers: 1
# dense_units: 16
# lr: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9500468969345093
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 800,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "trainer@output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\muhammad_yafi_079-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057701155
# last_update_time_since_epoch: 1721057701155
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 20
# type_id: 15
# uri: "output\\muhammad_yafi_079-pipeline\\Transform\\transformed_examples\\16"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059717552
# last_update_time_since_epoch: 1721059717552
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 23
# type_id: 24
# uri: "output\\muhammad_yafi_079-pipeline\\Transform\\transform_graph\\16"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059717553
# last_update_time_since_epoch: 1721059717553
# , artifact_type: id: 24
# name: "TransformGraph"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 18
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=18, input_dict={'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\muhammad_yafi_079-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057701155
# last_update_time_since_epoch: 1721057701155
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 20
# type_id: 15
# uri: "output\\muhammad_yafi_079-pipeline\\Transform\\transformed_examples\\16"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059717552
# last_update_time_since_epoch: 1721059717552
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 23
# type_id: 24
# uri: "output\\muhammad_yafi_079-pipeline\\Transform\\transform_graph\\16"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059717553
# last_update_time_since_epoch: 1721059717553
# , artifact_type: id: 24
# name: "TransformGraph"
# )]}, output_dict=defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model_run\\18"
# , artifact_type: name: "ModelRun"
# )]}), exec_properties={'module_path': 'trainer@output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl', 'train_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "train"\n  ]\n}', 'eval_args': '{\n  "num_steps": 800,\n  "splits": [\n    "eval"\n  ]\n}', 'custom_config': 'null'}, execution_output_uri='output\\muhammad_yafi_079-pipeline\\Trainer\\.system\\executor_execution\\18\\executor_output.pb', stateful_working_dir='output\\muhammad_yafi_079-pipeline\\Trainer\\.system\\stateful_working_dir\\20240715-230743.941046', tmp_dir='output\\muhammad_yafi_079-pipeline\\Trainer\\.system\\executor_execution\\18\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 800,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "trainer@output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "muhammad_yafi_079-pipeline"
# , pipeline_run_id='20240715-230743.941046')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'module_path': 'trainer@output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl', 'train_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "train"\n  ]\n}', 'eval_args': '{\n  "num_steps": 800,\n  "splits": [\n    "eval"\n  ]\n}', 'custom_config': 'null'} 'run_fn'
# INFO:absl:Installing 'output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\ANANG\\ML_Ops\\myenv\\Scripts\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\ANANG\\AppData\\Local\\Temp\\tmpkdwqpihy', 'output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl']
# INFO:absl:Successfully installed 'output\\muhammad_yafi_079-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+0a0df96bb52820b5dd50af9317dff22909d07c56d0ae9059e56f59d3f3ec5b23-py3-none-any.whl'.
# INFO:absl:Training model.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  gender_xf (InputLayer)         [(None, 4)]          0           []
#
#  hypertension_xf (InputLayer)   [(None, 3)]          0           []
#
#  heart_disease_xf (InputLayer)  [(None, 3)]          0           []
#
#  ever_married_xf (InputLayer)   [(None, 3)]          0           []
#
#  work_type_xf (InputLayer)      [(None, 4)]          0           []
#
#  Residence_type_xf (InputLayer)  [(None, 3)]         0           []
#
#  smoking_status_xf (InputLayer)  [(None, 4)]         0           []
#
#  age_xf (InputLayer)            [(None, 1)]          0           []
#
#  avg_glucose_level_xf (InputLay  [(None, 1)]         0           []
#  er)
#
#  bmi_xf (InputLayer)            [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 27)           0           ['gender_xf[0][0]',
#                                                                   'hypertension_xf[0][0]',
#                                                                   'heart_disease_xf[0][0]',
#                                                                   'ever_married_xf[0][0]',
#                                                                   'work_type_xf[0][0]',
#                                                                   'Residence_type_xf[0][0]',
#                                                                   'smoking_status_xf[0][0]',
#                                                                   'age_xf[0][0]',
#                                                                   'avg_glucose_level_xf[0][0]',
#                                                                   'bmi_xf[0][0]']
#
#  dense_4 (Dense)                (None, 256)          7168        ['concatenate_1[0][0]']
#
#  dense_5 (Dense)                (None, 64)           16448       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 16)           1040        ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 1)            17          ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 24,673
# Trainable params: 24,673
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.1638 - binary_accuracy: 0.9504 - val_loss: 0.1457 - val_binary_accuracy: 0.9543
# Epoch 2/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1393 - binary_accuracy: 0.9538 - val_loss: 0.1665 - val_binary_accuracy: 0.9452
# Epoch 3/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1236 - binary_accuracy: 0.9580 - val_loss: 0.2009 - val_binary_accuracy: 0.9482
# Epoch 4/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1117 - binary_accuracy: 0.9608 - val_loss: 0.2312 - val_binary_accuracy: 0.9513
# Epoch 5/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1008 - binary_accuracy: 0.9634 - val_loss: 0.2690 - val_binary_accuracy: 0.9431
# Epoch 6/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0896 - binary_accuracy: 0.9668 - val_loss: 0.3221 - val_binary_accuracy: 0.9421
# Epoch 7/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0812 - binary_accuracy: 0.9687 - val_loss: 0.3720 - val_binary_accuracy: 0.9381
# Epoch 8/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0756 - binary_accuracy: 0.9708 - val_loss: 0.4115 - val_binary_accuracy: 0.9421
# Epoch 9/10
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.0676 - binary_accuracy: 0.9734 - val_loss: 0.5005 - val_binary_accuracy: 0.9472
# Epoch 10/10
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.0643 - binary_accuracy: 0.9742 - val_loss: 0.4850 - val_binary_accuracy: 0.9432
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: output\muhammad_yafi_079-pipeline\Trainer\model\18\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\muhammad_yafi_079-pipeline\Trainer\model\18\Format-Serving\assets
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# INFO:absl:Training complete. Model written to output\muhammad_yafi_079-pipeline\Trainer\model\18\Format-Serving. ModelRun written to output\muhammad_yafi_079-pipeline\Trainer\model_run\18
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 18 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model_run\\18"
# , artifact_type: name: "ModelRun"
# )]}) for execution 18
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"stroke\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"hypertension\",\n        \"heart_disease\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\muhammad_yafi_079-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:321681,xor_checksum:1721056991,sum_checksum:1721056991"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057695551
# last_update_time_since_epoch: 1721057695551
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 30
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059932291
# last_update_time_since_epoch: 1721059932291
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [Artifact(artifact: id: 14
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057890599
# last_update_time_since_epoch: 1721057890599
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 19
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=19, input_dict={'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\muhammad_yafi_079-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:321681,xor_checksum:1721056991,sum_checksum:1721056991"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057695551
# last_update_time_since_epoch: 1721057695551
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 30
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059932291
# last_update_time_since_epoch: 1721059932291
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [Artifact(artifact: id: 14
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721057890599
# last_update_time_since_epoch: 1721057890599
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )]}, output_dict=defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}), exec_properties={'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "stroke"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "hypertension",\n        "heart_disease"\n      ]\n    }\n  ]\n}'}, execution_output_uri='output\\muhammad_yafi_079-pipeline\\Evaluator\\.system\\executor_execution\\19\\executor_output.pb', stateful_working_dir='output\\muhammad_yafi_079-pipeline\\Evaluator\\.system\\stateful_working_dir\\20240715-230743.941046', tmp_dir='output\\muhammad_yafi_079-pipeline\\Evaluator\\.system\\executor_execution\\19\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"stroke\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"hypertension\",\n        \"heart_disease\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "muhammad_yafi_079-pipeline"
# , pipeline_run_id='20240715-230743.941046')
# INFO:absl:udf_utils.get_fn {'example_splits': 'null', 'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "stroke"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "hypertension",\n        "heart_disease"\n      ]\n    }\n  ]\n}'} 'custom_eval_shared_model'
# INFO:absl:Adding default baseline ModelSpec based on the candidate ModelSpec provided. The candidate model will be called "candidate" and the baseline will be called "baseline": updated_config=
# model_specs {
#   name: "candidate"
#   label_key: "stroke"
# }
# model_specs {
#   name: "baseline"
#   label_key: "stroke"
#   is_baseline: true
# }
# slicing_specs {
# }
# slicing_specs {
#   feature_keys: "hypertension"
#   feature_keys: "heart_disease"
# }
# metrics_specs {
#   metrics {
#     class_name: "AUC"
#   }
#   metrics {
#     class_name: "Precision"
#   }
#   metrics {
#     class_name: "Recall"
#   }
#   metrics {
#     class_name: "ExampleCount"
#   }
#   metrics {
#     class_name: "BinaryAccuracy"
#     threshold {
#       value_threshold {
#         lower_bound {
#           value: 0.5
#         }
#       }
#       change_threshold {
#         absolute {
#           value: 0.0001
#         }
#         direction: HIGHER_IS_BETTER
#       }
#     }
#   }
# }
#
# INFO:absl:Using output\muhammad_yafi_079-pipeline\Trainer\model\18\Format-Serving as candidate model.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FA4293730> and <keras.engine.input_layer.InputLayer object at 0x0000020F8B4709D0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FA4293730> and <keras.engine.input_layer.InputLayer object at 0x0000020F8B4709D0>).
# INFO:absl:Using output\muhammad_yafi_079-pipeline\Trainer\model\7\Format-Serving as baseline model.
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FB3351F10> and <keras.engine.input_layer.InputLayer object at 0x0000020FB1D47D30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FB3351F10> and <keras.engine.input_layer.InputLayer object at 0x0000020FB1D47D30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FB57C1E20> and <keras.engine.input_layer.InputLayer object at 0x0000020FB333F340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020FB57C1E20> and <keras.engine.input_layer.InputLayer object at 0x0000020FB333F340>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020F89763700> and <keras.engine.input_layer.InputLayer object at 0x0000020FB58FC670>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000020F89763700> and <keras.engine.input_layer.InputLayer object at 0x0000020FB58FC670>).
# INFO:absl:Evaluation complete. Results written to output\muhammad_yafi_079-pipeline\Evaluator\evaluation\19.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From c:\Users\ANANG\ML_Ops\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From c:\Users\ANANG\ML_Ops\myenv\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result True written to output\muhammad_yafi_079-pipeline\Evaluator\blessing\19.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 19 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\evaluation\\19"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\blessing\\19"
# , artifact_type: name: "ModelBlessing"
# )]}) for execution 19
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model': [Artifact(artifact: id: 30
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059932291
# last_update_time_since_epoch: 1721059932291
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 33
# type_id: 33
# uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\7"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 14
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 30
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059961090
# last_update_time_since_epoch: 1721059961090
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 20
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=20, input_dict={'model': [Artifact(artifact: id: 30
# type_id: 28
# uri: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059932291
# last_update_time_since_epoch: 1721059932291
# , artifact_type: id: 28
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 33
# type_id: 33
# uri: "output\\muhammad_yafi_079-pipeline\\Evaluator\\blessing\\19"
# custom_properties {
#   key: "baseline_model"
#   value {
#     string_value: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\7"
#   }
# }
# custom_properties {
#   key: "baseline_model_id"
#   value {
#     int_value: 14
#   }
# }
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\muhammad_yafi_079-pipeline\\Trainer\\model\\18"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 30
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721059961090
# last_update_time_since_epoch: 1721059961090
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'push_destination': '{\n  "filesystem": {\n    "base_directory": "output\\\\serving_model"\n  }\n}', 'custom_config': 'null'}, execution_output_uri='output\\muhammad_yafi_079-pipeline\\Pusher\\.system\\executor_execution\\20\\executor_output.pb', stateful_working_dir='output\\muhammad_yafi_079-pipeline\\Pusher\\.system\\stateful_working_dir\\20240715-230743.941046', tmp_dir='output\\muhammad_yafi_079-pipeline\\Pusher\\.system\\executor_execution\\20\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240715-230743.941046"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "muhammad_yafi_079-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240715-230743.941046"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "muhammad_yafi_079-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "muhammad_yafi_079-pipeline"
# , pipeline_run_id='20240715-230743.941046')
# INFO:absl:Model version: 1721059961
# INFO:absl:Model written to serving path output\serving_model\1721059961.
# INFO:absl:Model pushed to output\muhammad_yafi_079-pipeline\Pusher\pushed_model\20.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 20 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\muhammad_yafi_079-pipeline\\Pusher\\pushed_model\\20"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 20
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
